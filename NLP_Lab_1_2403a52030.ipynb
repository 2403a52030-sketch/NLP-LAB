# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a52030-sketch/NLP-LAB/blob/main/NLP_Lab_1_2403a52030.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk spacy

# %%
import nltk
import spacy

# %%
# Download basic NLTK data
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install nltk spacy

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 90.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import nltk
import spacy
import pandas as pd

# %%
import pandas as pd

file_path = "/content/drive/MyDrive/nlp_text_dataset.csv"
df = pd.read_csv(file_path)

df.head()
# Out:
#    id                                               text       label
# 0   1     The weather is sunny and perfect for a picnic.     weather
# 1   2  Government announced a new policy for renewabl...        news
# 2   3       I love learning Natural Language Processing.   education
# 3   4                 The movie was boring and too long.     reviews
# 4   5     AI models are transforming healthcare systems.  technology

# %%
text_data = " ".join(df['text'].astype(str))

word_count = len(text_data.split())
print("Total number of words:", word_count)
# Out:
# Total number of words: 313

# %%
lower_text = text_data.lower()
print(lower_text[:500])  # first 500 characters
# Out:
# the weather is sunny and perfect for a picnic. government announced a new policy for renewable energy. i love learning natural language processing. the movie was boring and too long. ai models are transforming healthcare systems. heavy rains caused traffic jams across the city. the new mall opened with many international brands. students participated in a coding hackathon. the restaurant had delicious food but slow service. researchers introduced a new deep learning architecture. cloudy skies ar

# %%
print("Dataset loaded from Google Drive")
print("Total Word Count:", word_count)
print("Lowercase Text Sample:\n", lower_text[:300])
# Out:
# Dataset loaded from Google Drive
# Total Word Count: 313
# Lowercase Text Sample:
#  the weather is sunny and perfect for a picnic. government announced a new policy for renewable energy. i love learning natural language processing. the movie was boring and too long. ai models are transforming healthcare systems. heavy rains caused traffic jams across the city. the new mall opened w
